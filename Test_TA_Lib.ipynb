# %%
import pandas_datareader.data as web
import pandas as pd
import numpy as np
import talib as tl
import quandl
import matplotlib.pyplot as plt
import ta as ta
import datetime as dt
start_dt = '2014-03-22'
end_dt = '2017-03-27'

quandl.api_config.read_key ='LbAygJD_Pr-wzJCh72M1'

symbol = 'WIKI/AAPL'
symbol2 = 'WIKI/IBM'
max_holding = 100

price = quandl.get(symbol, start_date=start_dt, end_date=end_dt)
# price = price.sort_index(axis=0, level=None, ascending=False, inplace=True, kind='quicksort', na_position='last', sort_remaining=True, by=None)
# price = price.iloc[::-1]
price = price.dropna()
# dt.date.today()
price_test = quandl.get(symbol2, start_date=end_dt, end_date='2018-03-27')
# price_test = price_test.sort_index(axis=0, level=None, ascending=True, inplace=False, kind='quicksort', na_position='last', sort_remaining=True, by=None)
# price_test = price_test.iloc[::-1]
price_test = price_test.dropna()

# %%
price.tail
price_test.tail
# Out:
# <bound method NDFrame.tail of               Open     High      Low  Close      Volume  Ex-Dividend  \
# Date
# 2017-03-27  64.630  65.2200  64.3500  65.10  18614662.0          0.0
# 2017-03-28  64.960  65.4700  64.6500  65.29  20080358.0          0.0
# 2017-03-29  65.120  65.5000  64.9475  65.47  13618424.0          0.0
# 2017-03-30  65.420  65.9800  65.3600  65.71  15122823.0          0.0
# 2017-03-31  65.650  66.1900  65.4500  65.86  21040331.0          0.0
# 2017-04-03  65.810  65.9400  65.1900  65.55  20400871.0          0.0
# 2017-04-04  65.390  65.8100  65.2800  65.73  12997449.0          0.0
# 2017-04-05  66.300  66.3500  65.4443  65.56  21448594.0          0.0
# 2017-04-06  65.600  66.0550  65.4800  65.73  18103453.0          0.0
# 2017-04-07  65.850  65.9600  65.4400  65.68  14089274.0          0.0
# 2017-04-10  65.610  65.8200  65.3600  65.53  17952742.0          0.0
# 2017-04-11  65.600  65.6100  64.8500  65.48  18791533.0          0.0
# 2017-04-12  65.420  65.5100  65.1100  65.23  17108513.0          0.0
# 2017-04-13  65.290  65.8600  64.9500  64.95  17896483.0          0.0
# 2017-04-17  65.040  65.4900  65.0100  65.48  16689265.0          0.0
# 2017-04-18  65.330  65.7100  65.1600  65.39  15155611.0          0.0
# 2017-04-19  65.650  65.7500  64.8900  65.04  26992771.0          0.0
# 2017-04-20  65.460  65.7500  65.1400  65.50  22299477.0          0.0
# 2017-04-21  65.670  66.7000  65.4500  66.40  32522645.0          0.0
# 2017-04-24  67.480  67.6600  67.1000  67.53  29721254.0          0.0
# 2017-04-25  67.900  68.0400  67.6000  67.92  29983174.0          0.0
# 2017-04-26  68.080  68.3100  67.6200  67.83  25544417.0          0.0
# 2017-04-27  68.150  68.3800  67.5800  68.27  32219234.0          0.0
# 2017-04-28  68.910  69.1400  67.6900  68.46  38940853.0          0.0
# 2017-05-01  68.680  69.5500  68.5000  69.41  31304672.0          0.0
# 2017-05-02  69.710  69.7100  69.1300  69.30  23000828.0          0.0
# 2017-05-03  69.380  69.3800  68.7100  69.08  28725646.0          0.0
# 2018-03-20          1.0  93.050000  93.770000  93.000000   93.130000
# 2018-03-21          1.0  92.930000  94.050000  92.210000   92.480000
# 2018-03-22          1.0  91.265000  91.750000  89.660000   89.790000
# 2018-03-23          1.0  89.500000  90.460000  87.080000   87.180000
# 2018-03-26          1.0  90.610000  94.000000  90.400000   93.780000
# 2018-03-27          1.0  94.940000  95.139000  88.510000   89.470000
#
#             Adj. Volume
# Date
# 2017-03-27   18614662.0
# 2017-03-28   20080358.0
# 2017-03-29   13618424.0
# 2017-03-30   15122823.0
# 2017-03-31   21040331.0
# 2017-04-03   20400871.0
# 2017-04-04   12997449.0
# 2017-04-05   21448594.0
# 2017-04-06   18103453.0
# 2017-04-07   14089274.0
# 2017-04-10   17952742.0
# 2017-04-11   18791533.0
# 2017-04-12   17108513.0
# 2017-04-13   17896483.0
# 2017-04-17   16689265.0
# 2017-04-18   15155611.0
# 2017-04-19   26992771.0
# 2017-04-20   22299477.0
# 2017-04-21   32522645.0
# 2017-04-24   29721254.0
# 2017-04-25   29983174.0
# 2017-04-26   25544417.0
# 2017-04-27   32219234.0
# 2017-04-28   38940853.0
# 2017-05-01   31304672.0
# 2017-05-02   23000828.0
# 2017-05-03   28725646.0
# 2017-05-04   21421413.0
# 2017-05-05   18882845.0
# 2017-05-08   18446053.0
# ...                 ...
# 2018-02-13   26200053.0
# 2018-02-14   34314101.0
# 2018-02-15   27407914.0
# 2018-02-16   30188535.0
# 2018-02-20   30107057.0
# 2018-02-21   26081953.0
# 2018-02-22   22723756.0
# 2018-02-23   25779955.0
# 2018-02-26   29760276.0
# 2018-02-27   25540755.0
# 2018-02-28   29314525.0
# 2018-03-01   37135561.0
# 2018-03-02   32830389.0
# 2018-03-05   23901578.0
# 2018-03-06   22175776.0
# 2018-03-07   26716127.0
# 2018-03-08   24861307.0
# 2018-03-09   36145524.0
# 2018-03-12   25333720.0
# 2018-03-13   34445391.0
# 2018-03-14   31576898.0
# 2018-03-15   26279014.0
# 2018-03-16   47329521.0
# 2018-03-19   31752589.0
# 2018-03-20   21787780.0
# 2018-03-21   23753263.0
# 2018-03-22   37578166.0
# 2018-03-23   42159397.0
# 2018-03-26   55031149.0
# 2018-03-27   53704562.0
#
# [252 rows x 12 columns]>

# %%
X = pd.DataFrame(index=price.index, data={'bollinger_hband_indicator': np.array([np.nan] * price.index.shape[0])})

X['bollinger_hband_indicator'] = ta.bollinger_hband_indicator(price['Adj. Close'], n=20, ndev=2, fillna=True)
X['bollinger_lband_indicator'] = ta.bollinger_lband_indicator(price['Adj. Close'], n=20, ndev=2, fillna=True)
X['ema_indicator_21'] = ta.ema_indicator(price['Adj. Close'], n=21, fillna=True)
X['ema_indicator_50'] = ta.ema_indicator(price['Adj. Close'], n=50, fillna=True)
X['ema_indicator_200'] = ta.ema_indicator(price['Adj. Close'], n=200, fillna=True)
X['acc_dist_index'] = ta.acc_dist_index(price['High'], price['Low'], price['Adj. Close'], price['Volume'])
X['on_balance_volume'] = ta.on_balance_volume(price['Adj. Close'], price['Volume'], fillna=True)
X['chaikin_money_flow'] = ta.chaikin_money_flow(price['High'], price['Low'], price['Adj. Close'], price['Volume'], n=20, fillna=True)
X['force_index'] = ta.force_index( price['Adj. Close'], price['Volume'], n=2, fillna=True)
X['ease_of_movement'] = ta.ease_of_movement(price['High'], price['Low'], price['Adj. Close'], price['Volume'], n=20, fillna=True)
X['volume_price_trend'] = ta.volume_price_trend(price['Adj. Close'], price['Volume'],fillna=True)
X['negative_volume_index'] = ta.negative_volume_index(price['Adj. Close'], price['Volume'],fillna=True)
X['average_true_range'] = ta.average_true_range(price['High'], price['Low'], price['Adj. Close'], n=14, fillna=True)
# X['KCU'] = ta.keltner_channel_hband_indicator(price['High'], price['Low'], price['Adj. Close'], n=10, fillna=True)
X['keltner_channel_lband_indicator'] = ta.keltner_channel_lband_indicator(price['High'], price['Low'], price['Adj. Close'], n=10, fillna=True)
X['donchian_channel_hband_indicator'] = ta.donchian_channel_hband_indicator(price['Adj. Close'], n=20, fillna=True)
X['donchian_channel_lband_indicator'] = ta.donchian_channel_lband_indicator(price['Adj. Close'], n=20, fillna=True)
X['macd_signal'] = ta.macd_signal(price['Adj. Close'], n_fast=12, n_slow=26, n_sign=9, fillna=True)
X['adx_pos'] = ta.adx_pos(price['High'], price['Low'], price['Adj. Close'], n=14, fillna=True)
X['adx_neg'] = ta.adx_neg(price['High'], price['Low'], price['Adj. Close'], n=14, fillna=True)
X['vortex_indicator_neg'] = ta.vortex_indicator_neg(price['High'], price['Low'], price['Adj. Close'], n=14, fillna=True)
X['vortex_indicator_pos'] = ta.vortex_indicator_pos(price['High'], price['Low'], price['Adj. Close'], n=14, fillna=True)
X['trix'] = ta.trix(price['Adj. Close'], n=15, fillna=True)
X['mass_index'] = ta.mass_index(price['High'], price['Low'], n=9, n2 = 25, fillna=True)
X['cci'] = ta.cci(price['High'], price['Low'], price['Adj. Close'], n=20, c=1, fillna=True)
X['dpo'] = ta.dpo(price['Adj. Close'], n=20, fillna=True)
X['kst_sig'] = ta.kst_sig(price['Adj. Close'], r1=10, r2=15, r3=20, r4=30, n1=10, n2=10, n3=10, n4=15, nsig=9, fillna=True)
X['ichimoku_a'] = ta.ichimoku_a(price['High'], price['Low'], n1=9, n2=26, fillna=True)
X['ichimoku_b'] = ta.ichimoku_b(price['High'], price['Low'], n2=26, n3=52, fillna=True)
X['money_flow_index'] = ta.money_flow_index(price['High'], price['Low'], price['Adj. Close'], price['Volume'], n=14, fillna=True)
X['rsi'] = ta.rsi(price['Adj. Close'], n=14, fillna=True)
X['tsi'] = ta.tsi(price['Adj. Close'], r=25, s=13, fillna=True)
X['uo'] = ta.uo(price['High'], price['Low'], price['Adj. Close'],s=7,m=14,l=28,ws=4,wm=2,wl=1,fillna=True)
X['stoch_signal'] = ta.stoch_signal(price['High'], price['Low'], price['Adj. Close'],n=14,d_n=3,fillna=True)
X['wr'] = ta.wr(price['High'], price['Low'], price['Adj. Close'],lbp=14,fillna=True)
# 2017-03-22     52.750615   -43.922123   4.052221      1.129863
# 2017-03-23     44.117577   -52.547339   3.732593     -0.353557
# 2017-03-24     48.717692   -57.377460   3.487108     -0.198694
# 2017-03-27     45.612615   -53.237357   2.963018      0.170648
#
# [759 rows x 36 columns]>

# %%
X_test = pd.DataFrame(index=price_test.index, data={'bollinger_hband_indicator': np.array([np.nan] * price_test.index.shape[0])})


X_test['bollinger_hband_indicator'] = ta.bollinger_hband_indicator(price_test['Adj. Close'], n=20, ndev=2, fillna=True)
X_test['bollinger_lband_indicator'] = ta.bollinger_lband_indicator(price_test['Adj. Close'], n=20, ndev=2, fillna=True)
X_test['ema_indicator_21'] = ta.ema_indicator(price_test['Adj. Close'], n=21, fillna=True)
X_test['ema_indicator_50'] = ta.ema_indicator(price_test['Adj. Close'], n=50, fillna=True)
X_test['ema_indicator_200'] = ta.ema_indicator(price_test['Adj. Close'], n=200, fillna=True)
X_test['acc_dist_index'] = ta.acc_dist_index(price_test['High'], price_test['Low'], price_test['Adj. Close'], price_test['Volume'])
X_test['on_balance_volume'] = ta.on_balance_volume(price_test['Adj. Close'], price_test['Volume'], fillna=True)
X_test['chaikin_money_flow'] = ta.chaikin_money_flow(price_test['High'], price_test['Low'], price_test['Adj. Close'], price_test['Volume'], n=20, fillna=True)
X_test['force_index'] = ta.force_index( price_test['Adj. Close'], price_test['Volume'], n=2, fillna=True)
X_test['ease_of_movement'] = ta.ease_of_movement(price_test['High'], price_test['Low'], price_test['Adj. Close'], price_test['Volume'], n=20, fillna=True)
X_test['volume_price_trend'] = ta.volume_price_trend(price_test['Adj. Close'], price_test['Volume'],fillna=True)
X_test['negative_volume_index'] = ta.negative_volume_index(price_test['Adj. Close'], price_test['Volume'],fillna=True)
X_test['average_true_range'] = ta.average_true_range(price_test['High'], price_test['Low'], price_test['Adj. Close'], n=14, fillna=True)
# X_test['KCU'] = ta.keltner_channel_hband_indicator(price_test['High'], price_test['Low'], price_test['Adj. Close'], n=10, fillna=True)
X_test['keltner_channel_lband_indicator'] = ta.keltner_channel_lband_indicator(price_test['High'], price_test['Low'], price_test['Adj. Close'], n=10, fillna=True)
X_test['donchian_channel_hband_indicator'] = ta.donchian_channel_hband_indicator(price_test['Adj. Close'], n=20, fillna=True)
X_test['donchian_channel_lband_indicator'] = ta.donchian_channel_lband_indicator(price_test['Adj. Close'], n=20, fillna=True)
X_test['macd_signal'] = ta.macd_signal(price_test['Adj. Close'], n_fast=12, n_slow=26, n_sign=9, fillna=True)
X_test['adx_pos'] = ta.adx_pos(price_test['High'], price_test['Low'], price_test['Adj. Close'], n=14, fillna=True)
X_test['adx_neg'] = ta.adx_neg(price_test['High'], price_test['Low'], price_test['Adj. Close'], n=14, fillna=True)
X_test['vortex_indicator_neg'] = ta.vortex_indicator_neg(price_test['High'], price_test['Low'], price_test['Adj. Close'], n=14, fillna=True)
X_test['vortex_indicator_pos'] = ta.vortex_indicator_pos(price_test['High'], price_test['Low'], price_test['Adj. Close'], n=14, fillna=True)
X_test['trix'] = ta.trix(price_test['Adj. Close'], n=15, fillna=True)
X_test['mass_index'] = ta.mass_index(price_test['High'], price_test['Low'], n=9, n2 = 25, fillna=True)
X_test['cci'] = ta.cci(price_test['High'], price_test['Low'], price_test['Adj. Close'], n=20, c=1, fillna=True)
X_test['dpo'] = ta.dpo(price_test['Adj. Close'], n=20, fillna=True)
X_test['kst_sig'] = ta.kst_sig(price_test['Adj. Close'], r1=10, r2=15, r3=20, r4=30, n1=10, n2=10, n3=10, n4=15, nsig=9, fillna=True)
X_test['ichimoku_a'] = ta.ichimoku_a(price_test['High'], price_test['Low'], n1=9, n2=26, fillna=True)
X_test['ichimoku_b'] = ta.ichimoku_b(price_test['High'], price_test['Low'], n2=26, n3=52, fillna=True)
X_test['money_flow_index'] = ta.money_flow_index(price_test['High'], price_test['Low'], price_test['Adj. Close'], price_test['Volume'], n=14, fillna=True)
X_test['rsi'] = ta.rsi(price_test['Adj. Close'], n=14, fillna=True)
X_test['tsi'] = ta.tsi(price_test['Adj. Close'], r=25, s=13, fillna=True)
X_test['uo'] = ta.uo(price_test['High'], price_test['Low'], price_test['Adj. Close'],s=7,m=14,l=28,ws=4,wm=2,wl=1,fillna=True)
X_test['stoch_signal'] = ta.stoch_signal(price_test['High'], price_test['Low'], price_test['Adj. Close'],n=14,d_n=3,fillna=True)
X_test['wr'] = ta.wr(price_test['High'], price_test['Low'], price_test['Adj. Close'],lbp=14,fillna=True)
X_test['ao'] = ta.ao(price_test['Low'], price_test['Adj. Close'], s=5, l=34, fillna=True)
X_test['daily_return'] = ta.daily_return(price_test['Adj. Close'], fillna=True)

# %%
# X = X.dropna()
# X_test = X_test.dropna()

# %%
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import StratifiedKFold

# %%
# Create test and training data
# X.dropna()
cols = X.columns

X0 = (X-X.min())/(X.max()-X.min())
X0 = X0.loc[:,cols[0:-1]]
X0 = X0.iloc[1:,]
X0.dropna()
X0 = X0.values
#

Y0 = X.loc[:,cols[-1]]
Y0 = Y0.iloc[0:-1]
Y0 = Y0.values
Y0[Y0>0] = 1
Y0[Y0<0] = 0

X0_test = (X_test-X_test.min())/(X_test.max()-X_test.min())
X0_test = X0_test.loc[:,cols[0:-1]]
X0_test = X0_test.iloc[1:,]
X0_test.dropna()
X0_test = X0_test.values

Y0_test = X_test.loc[:,cols[-1]]
Y0_test = Y0_test.iloc[0:-1]
Y0_test = Y0_test.values
Y0_test[Y0_test>0] = 1
Y0_test[Y0_test<0] = 0

# %%
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)

# define 10-fold cross validation test harness
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
cvscores = []
kfold
# Out:
# StratifiedKFold(n_splits=10, random_state=7, shuffle=True)

# %%
for train, test in kfold.split(X0, Y0): #Only works for classification problems
    # create model
    model = Sequential()
    model.add(Dense(50, input_dim=35, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    # Compile model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.fit(X0[train], Y0[train],  batch_size=10, epochs=150, verbose=0)
    # evaluate the model
    scores = model.evaluate(X0[test], Y0[test], verbose=0)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
# Out:
# acc: 75.32%
# acc: 64.94%
# acc: 68.42%
# acc: 69.74%
# acc: 71.05%
# acc: 66.67%
# acc: 61.33%
# acc: 69.33%
# acc: 77.33%
# acc: 62.67%

# %%
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
# Out:
# 68.68% (+/- 4.84%)

# %%
# create model
model = Sequential()
model.add(Dense(50, input_dim=35, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X0, Y0,  batch_size=10, epochs=1500, verbose=0)

# %%
# evaluate the model
scores = model.evaluate(X0_test, Y0_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# acc: 56.97%

# %%
# X0.to_clipboard()

# %%
# X.to_clipboard()

# %%
# Y.to_clipboard()

# %%
out = model.predict(X0_test, batch_size=None, verbose=0, steps=None)

# %% [markdown]
# # Do some testing on forward information

# %%
i = 20
# tmp = ta.bollinger_hband_indicator(price.loc[0:i,'Adj. Close'], n=20, ndev=2, fillna=True)
# tmp
cols = price.columns
px = price.loc[:,['Adj. Close','High','Low','Volume']]
# px = px.sort_index(axis=0, level=None, ascending=True, inplace=False, kind='quicksort', na_position='last', sort_remaining=True, by=None)
tmp = ta.bollinger_lband_indicator(px.iloc[0:i,0], n=20, ndev=2, fillna=True)
tmp[-1]
np.size(price,0)
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False])

# %%
cols = X.columns
idx = np.where(cols == name)
ctr = np.where(cols == name)
tmp = ta.bollinger_hband_indicator(px.iloc[0:i,0], n=20, ndev=2, fillna=True)
idx = np.where(cols == name)
ctr = int(idx[0])
ctr
# Out:
# 0

# %% [markdown]
# ## Run the analysis on expanding windows to make sure there is no forward info used

# %%
#check that the output of the ta library does not use forward information
# ctr = 0
# Xr = pd.DataFrame(index=price.index, data={'bollinger_hband_indicator': np.array([np.nan] * price.index.shape[0])})
Xr = X
Xr = np.nan
for name in X.columns:
    Xr[name] = 0
    Xr.dropna()
    print('Processing = {0}'.format(name))
    idx = np.where(cols == name)
    ctr = int(idx[0])
    for i in range(np.size(price.index)):
        if (i >= 10):
            try:
                if (name == 'bollinger_hband_indicator'):
                    tmp = ta.bollinger_hband_indicator(px.iloc[0:i,0], n=20, ndev=2, fillna=True)
                elif (name == 'bollinger_lband_indicator'):
                    tmp = ta.bollinger_lband_indicator(px.iloc[0:i,0], n=20, ndev=2, fillna=True)
                elif (name == 'ema_indicator_21'):
                    tmp = ta.ema_indicator(px.iloc[0:i,0], n=21, fillna=True)
                elif (name == 'ema_indicator_50'):
                    tmp = ta.ema_indicator(px.iloc[0:i,0], n=50, fillna=True)
                elif (name == 'ema_indicator_200'):
                    tmp = ta.ema_indicator(px.iloc[0:i,0], n=200, fillna=True)
                elif (name == 'acc_dist_index'):
                    tmp = ta.acc_dist_index(px.iloc[0:i,1], px.iloc[0:i,2], px.iloc[0:i,0], px.iloc[0:i,3])
                elif (name == 'on_balance_volume'):
                    tmp = ta.on_balance_volume(px.iloc[0:i,0], px.iloc[0:i,3], fillna=True)
                elif (name == 'chaikin_money_flow'):
                    tmp = ta.chaikin_money_flow(px.iloc[0:i,1], px.iloc[0:i,2], px.iloc[0:i,0], px.iloc[0:i,3], n=20, fillna=True)
                elif (name == 'force_index'):
                    tmp = ta.force_index(px.iloc[0:i,0], px.iloc[0:i,3], n=2, fillna=True)
                elif (name == 'ease_of_movement'):
                    tmp = ta.ease_of_movement(px.iloc[0:i,1], px.iloc[0:i,2], px.iloc[0:i,0], px.iloc[0:i,3], n=20, fillna=True)
                elif (name == 'volume_price_trend'):
                    tmp = ta.volume_price_trend(px.iloc[0:i,0], px.iloc[0:i,3],fillna=True)
                elif(name == 'negative_volume_index'):
                    tmp = ta.negative_volume_index(px.iloc[0:i,0], px.iloc[0:i,3],fillna=True)
                elif(name == 'average_true_range'):
                    tmp = ta.average_true_range(px.iloc[0:i,1], px.iloc[0:i,2], px.iloc[0:i,0], n=14, fillna=True)
                elif(name == 'keltner_channel_hband_indicator'):
                    tmp = ta.keltner_channel_hband_indicator(px.iloc[0:i,1], px.iloc[0:i,2], px.iloc[0:i,0], n=10, fillna=True)
                elif(name == 'keltner_channel_lband_indicator'):
                    tmp = ta.keltner_channel_lband_indicator(px.iloc[0:i,1], px.iloc[0:i,2], px.iloc[0:i,0], n=10, fillna=True)
                elif(name == 'donchian_channel_hband_indicator'):    
                    tmp = ta.donchian_channel_hband_indicator(px.iloc[0:i,0], n=20, fillna=True)
                elif(name == 'donchian_channel_lband_indicator'):
                    tmp = ta.donchian_channel_lband_indicator(px.iloc[0:i,0], n=20, fillna=True)
                elif(name == 'macd_signal'):
                    tmp = ta.macd_signal(px.iloc[0:i,0], n_fast=12, n_slow=26, n_sign=9, fillna=True)
                elif(name == 'adx_pos'):
                    tmp = ta.adx_pos(px.iloc[0:i,1], px.iloc[0:i,2], px.iloc[0:i,0], n=14, fillna=True)
                elif(name == 'adx_neg'):
                    tmp = ta.adx_neg(px.iloc[0:i,1], px.iloc[0:i,2], px.iloc[0:i,0], n=14, fillna=True)
                elif(name == 'vortex_indicator_neg'):
                    tmp = ta.vortex_indicator_neg(px.iloc[0:i,1], px.iloc[0:i,2], px.iloc[0:i,0], n=14, fillna=True)
                elif(name == 'vortex_indicator_pos'):
                    tmp = ta.vortex_indicator_pos(px.iloc[0:i,1], px.iloc[0:i,2], px.iloc[0:i,0], n=14, fillna=True)
                elif(name == 'trix'):
                    tmp = ta.trix(px.iloc[0:i,0], n=15, fillna=True)
                elif(name == 'mass_index'):
                    tmp = ta.mass_index(px.iloc[0:i,1], px.iloc[0:i,2], n=9, n2 = 25, fillna=True)
                elif(name == 'cci'):
                    tmp = ta.cci(px.iloc[0:i,1], px.iloc[0:i,2], px.iloc[0:i,0], n=20, c=0.015, fillna=True)
                elif(name == 'dpo'):
                    tmp = ta.dpo(px.iloc[0:i,0], n=20, fillna=True)
                elif(name == 'kst_sig'):
                    tmp = ta.kst_sig(px.iloc[0:i,0], r1=10, r2=15, r3=20, r4=30, n1=10, n2=10, n3=10, n4=15, nsig=9, fillna=True)
                elif(name == 'ichimoku_a'):
                    tmp = ta.ichimoku_a(px.iloc[0:i,1], px.iloc[0:i,2], n1=9, n2=26, fillna=True)
                elif(name == 'ichimoku_b'):
                    tmp = ta.ichimoku_b(px.iloc[0:i,1], px.iloc[0:i,2], n2=26, n3=52, fillna=True)
                elif(name == 'money_flow_index'):
                    tmp = ta.money_flow_index(px.iloc[0:i,1], px.iloc[0:i,2], px.iloc[0:i,0], px.iloc[0:i,3], n=14, fillna=True)
                elif(name == 'rsi'):
                    tmp = ta.rsi(px.iloc[0:i,1], n=14, fillna=True)
                elif(name == 'tsi'):
                    tmp = ta.tsi(px.iloc[0:i,0], r=25, s=13, fillna=True)
                elif(name == 'uo'):
                    tmp = ta.uo(px.iloc[0:i,1], px.iloc[0:i,2], px.iloc[0:i,0],s=7,m=14,l=28,ws=4,wm=2,wl=1,fillna=True)
                elif(name == 'stoch_signal'):
                    tmp = ta.stoch_signal(px.iloc[0:I,1], px.iloc[0:i,2], px.iloc[0:i,0],n=14,d_n=3,fillna=True)
                elif(name == 'wr'):
                    tmp = ta.wr(px.iloc[0:i,1], px.iloc[0:i,2], px.iloc[0:i,0],lbp=14,fillna=True)
                elif(name == 'ao'):
                    tmp = ta.ao(px.iloc[0:i,2], px.iloc[0:i,0], s=5, l=34, fillna=True)
                elif(name == 'daily_return'):
                    tmp = ta.daily_return(px.iloc[0:i,0], fillna=True)
            except:
                print('Error in name={0}, i={1}, ctr={2}'.format(name,i,ctr))
                tmp = [0]
                
            Xr.iloc[i,int(ctr)] = tmp[-1] 
#     ctr += 1
# Out:
# Processing = bollinger_hband_indicator
# Processing = bollinger_lband_indicator
# Processing = ema_indicator_21
# Processing = ema_indicator_50
# Processing = ema_indicator_200
# Processing = acc_dist_index
# Processing = on_balance_volume
# Processing = chaikin_money_flow
# Processing = force_index
# Processing = ease_of_movement
# Processing = volume_price_trend
# Processing = negative_volume_index
# Processing = average_true_range
# Processing = keltner_channel_lband_indicator
# Processing = donchian_channel_hband_indicator
# Processing = donchian_channel_lband_indicator
# Processing = macd_signal
# Processing = adx_pos
# Error in name=adx_pos, i=10, ctr=17
# Error in name=adx_pos, i=11, ctr=17
# Error in name=adx_pos, i=12, ctr=17
# Error in name=adx_pos, i=13, ctr=17
# Processing = adx_neg
# Error in name=adx_neg, i=10, ctr=18
# Error in name=adx_neg, i=11, ctr=18
# Error in name=adx_neg, i=12, ctr=18
# Error in name=adx_neg, i=13, ctr=18
# Processing = vortex_indicator_neg
# Processing = vortex_indicator_pos
# Processing = trix
# Processing = mass_index
# Processing = cci
# Processing = dpo
# Processing = kst_sig
# Processing = ichimoku_a
# Processing = ichimoku_b
# Processing = money_flow_index
# Processing = rsi
# Processing = tsi
# Processing = uo
# Processing = stoch_signal
# Error in name=stoch_signal, i=10, ctr=32
# Error in name=stoch_signal, i=11, ctr=32
# Error in name=stoch_signal, i=12, ctr=32
# Error in name=stoch_signal, i=13, ctr=32
# Error in name=stoch_signal, i=14, ctr=32
# Error in name=stoch_signal, i=15, ctr=32
# Error in name=stoch_signal, i=16, ctr=32
# Error in name=stoch_signal, i=17, ctr=32
# Error in name=stoch_signal, i=18, ctr=32
# Error in name=stoch_signal, i=19, ctr=32
# Error in name=stoch_signal, i=20, ctr=32
# Error in name=stoch_signal, i=21, ctr=32
# Error in name=stoch_signal, i=22, ctr=32
# Error in name=stoch_signal, i=23, ctr=32
# Error in name=stoch_signal, i=24, ctr=32
# Error in name=stoch_signal, i=25, ctr=32
# Error in name=stoch_signal, i=26, ctr=32
# Error in name=stoch_signal, i=27, ctr=32
# Error in name=stoch_signal, i=28, ctr=32
# Error in name=stoch_signal, i=29, ctr=32
# Error in name=stoch_signal, i=30, ctr=32
# Error in name=stoch_signal, i=31, ctr=32
# Error in name=stoch_signal, i=32, ctr=32
# Error in name=stoch_signal, i=33, ctr=32
# Error in name=stoch_signal, i=34, ctr=32
# Error in name=stoch_signal, i=35, ctr=32
# Error in name=stoch_signal, i=36, ctr=32
# Error in name=stoch_signal, i=37, ctr=32
# Error in name=stoch_signal, i=38, ctr=32
# Error in name=stoch_signal, i=39, ctr=32
# Error in name=stoch_signal, i=40, ctr=32
# Error in name=stoch_signal, i=41, ctr=32
# Error in name=stoch_signal, i=42, ctr=32
# Error in name=stoch_signal, i=43, ctr=32
# Error in name=stoch_signal, i=44, ctr=32
# Error in name=stoch_signal, i=45, ctr=32
# Error in name=stoch_signal, i=46, ctr=32
# Error in name=stoch_signal, i=47, ctr=32
# Error in name=stoch_signal, i=48, ctr=32
# Error in name=stoch_signal, i=49, ctr=32
# Error in name=stoch_signal, i=50, ctr=32
# Error in name=stoch_signal, i=51, ctr=32
# Error in name=stoch_signal, i=52, ctr=32
# Error in name=stoch_signal, i=53, ctr=32
# Error in name=stoch_signal, i=54, ctr=32
# Error in name=stoch_signal, i=55, ctr=32
# Error in name=stoch_signal, i=56, ctr=32
# Error in name=stoch_signal, i=57, ctr=32
# Error in name=stoch_signal, i=58, ctr=32
# Error in name=stoch_signal, i=59, ctr=32
# Error in name=stoch_signal, i=60, ctr=32
# Error in name=stoch_signal, i=61, ctr=32
# Error in name=stoch_signal, i=62, ctr=32
# Error in name=stoch_signal, i=63, ctr=32
# Error in name=stoch_signal, i=64, ctr=32
# Error in name=stoch_signal, i=65, ctr=32
# Error in name=stoch_signal, i=66, ctr=32
# Error in name=stoch_signal, i=67, ctr=32
# Error in name=stoch_signal, i=68, ctr=32
# Error in name=stoch_signal, i=69, ctr=32
# Error in name=stoch_signal, i=70, ctr=32
# Error in name=stoch_signal, i=71, ctr=32
# Error in name=stoch_signal, i=72, ctr=32
# Error in name=stoch_signal, i=73, ctr=32
# Error in name=stoch_signal, i=74, ctr=32
# Error in name=stoch_signal, i=75, ctr=32
# Error in name=stoch_signal, i=76, ctr=32
# Error in name=stoch_signal, i=77, ctr=32
# Error in name=stoch_signal, i=78, ctr=32
# Error in name=stoch_signal, i=79, ctr=32
# Error in name=stoch_signal, i=80, ctr=32
# Error in name=stoch_signal, i=81, ctr=32
# Error in name=stoch_signal, i=82, ctr=32
# Error in name=stoch_signal, i=83, ctr=32
# Error in name=stoch_signal, i=84, ctr=32
# Error in name=stoch_signal, i=85, ctr=32
# Error in name=stoch_signal, i=86, ctr=32
# Error in name=stoch_signal, i=87, ctr=32
# Error in name=stoch_signal, i=88, ctr=32
# Error in name=stoch_signal, i=89, ctr=32
# Error in name=stoch_signal, i=90, ctr=32
# Error in name=stoch_signal, i=91, ctr=32
# Error in name=stoch_signal, i=92, ctr=32
# Error in name=stoch_signal, i=93, ctr=32
# Error in name=stoch_signal, i=94, ctr=32
# Error in name=stoch_signal, i=95, ctr=32
# Error in name=stoch_signal, i=96, ctr=32
# Error in name=stoch_signal, i=97, ctr=32
# Error in name=stoch_signal, i=98, ctr=32
# Error in name=stoch_signal, i=99, ctr=32
# Error in name=stoch_signal, i=100, ctr=32
# Error in name=stoch_signal, i=101, ctr=32
# Error in name=stoch_signal, i=102, ctr=32
# Error in name=stoch_signal, i=103, ctr=32
# Error in name=stoch_signal, i=104, ctr=32
# Error in name=stoch_signal, i=105, ctr=32
# Error in name=stoch_signal, i=106, ctr=32
# Error in name=stoch_signal, i=107, ctr=32
# Error in name=stoch_signal, i=108, ctr=32
# Error in name=stoch_signal, i=109, ctr=32
# Error in name=stoch_signal, i=110, ctr=32
# Error in name=stoch_signal, i=111, ctr=32
# Error in name=stoch_signal, i=112, ctr=32
# Error in name=stoch_signal, i=113, ctr=32
# Error in name=stoch_signal, i=114, ctr=32
# Error in name=stoch_signal, i=115, ctr=32
# Error in name=stoch_signal, i=116, ctr=32
# Error in name=stoch_signal, i=117, ctr=32
# Error in name=stoch_signal, i=118, ctr=32
# Error in name=stoch_signal, i=119, ctr=32
# Error in name=stoch_signal, i=120, ctr=32
# Error in name=stoch_signal, i=121, ctr=32
# Error in name=stoch_signal, i=122, ctr=32
# Error in name=stoch_signal, i=123, ctr=32
# Error in name=stoch_signal, i=124, ctr=32
# Error in name=stoch_signal, i=125, ctr=32
# Error in name=stoch_signal, i=126, ctr=32
# Error in name=stoch_signal, i=127, ctr=32
# Error in name=stoch_signal, i=128, ctr=32
# Error in name=stoch_signal, i=129, ctr=32
# Error in name=stoch_signal, i=130, ctr=32
# Error in name=stoch_signal, i=131, ctr=32
# Error in name=stoch_signal, i=132, ctr=32
# Error in name=stoch_signal, i=133, ctr=32
# Error in name=stoch_signal, i=134, ctr=32
# Error in name=stoch_signal, i=135, ctr=32
# Error in name=stoch_signal, i=136, ctr=32
# Error in name=stoch_signal, i=137, ctr=32
# Error in name=stoch_signal, i=138, ctr=32
# Error in name=stoch_signal, i=139, ctr=32
# Error in name=stoch_signal, i=140, ctr=32
# Error in name=stoch_signal, i=141, ctr=32
# Error in name=stoch_signal, i=142, ctr=32
# Error in name=stoch_signal, i=143, ctr=32
# Error in name=stoch_signal, i=144, ctr=32
# Error in name=stoch_signal, i=145, ctr=32
# Error in name=stoch_signal, i=146, ctr=32
# Error in name=stoch_signal, i=147, ctr=32
# Error in name=stoch_signal, i=148, ctr=32
# Error in name=stoch_signal, i=149, ctr=32
# Error in name=stoch_signal, i=150, ctr=32
# Error in name=stoch_signal, i=151, ctr=32
# Error in name=stoch_signal, i=152, ctr=32
# Error in name=stoch_signal, i=153, ctr=32
# Error in name=stoch_signal, i=154, ctr=32
# Error in name=stoch_signal, i=155, ctr=32
# Error in name=stoch_signal, i=156, ctr=32
# Error in name=stoch_signal, i=157, ctr=32
# Error in name=stoch_signal, i=158, ctr=32
# Error in name=stoch_signal, i=159, ctr=32
# Error in name=stoch_signal, i=160, ctr=32
# Error in name=stoch_signal, i=161, ctr=32
# Error in name=stoch_signal, i=162, ctr=32
# Error in name=stoch_signal, i=163, ctr=32
# Error in name=stoch_signal, i=164, ctr=32
# Error in name=stoch_signal, i=165, ctr=32
# Error in name=stoch_signal, i=166, ctr=32
# Error in name=stoch_signal, i=167, ctr=32
# Error in name=stoch_signal, i=168, ctr=32
# Error in name=stoch_signal, i=169, ctr=32
# Error in name=stoch_signal, i=170, ctr=32
# Error in name=stoch_signal, i=171, ctr=32
# Error in name=stoch_signal, i=172, ctr=32
# Error in name=stoch_signal, i=173, ctr=32
# Error in name=stoch_signal, i=174, ctr=32
# Error in name=stoch_signal, i=175, ctr=32
# Error in name=stoch_signal, i=176, ctr=32
# Error in name=stoch_signal, i=177, ctr=32
# Error in name=stoch_signal, i=178, ctr=32
# Error in name=stoch_signal, i=179, ctr=32
# Error in name=stoch_signal, i=180, ctr=32
# Error in name=stoch_signal, i=181, ctr=32
# Error in name=stoch_signal, i=182, ctr=32
# Error in name=stoch_signal, i=183, ctr=32
# Error in name=stoch_signal, i=184, ctr=32
# Error in name=stoch_signal, i=185, ctr=32
# Error in name=stoch_signal, i=186, ctr=32
# Error in name=stoch_signal, i=187, ctr=32
# Error in name=stoch_signal, i=188, ctr=32
# Error in name=stoch_signal, i=189, ctr=32
# Error in name=stoch_signal, i=190, ctr=32
# Error in name=stoch_signal, i=191, ctr=32
# Error in name=stoch_signal, i=192, ctr=32
# Error in name=stoch_signal, i=193, ctr=32
# Error in name=stoch_signal, i=194, ctr=32
# Error in name=stoch_signal, i=195, ctr=32
# Error in name=stoch_signal, i=196, ctr=32
# Error in name=stoch_signal, i=197, ctr=32
# Error in name=stoch_signal, i=198, ctr=32
# Error in name=stoch_signal, i=199, ctr=32
# Error in name=stoch_signal, i=200, ctr=32
# Error in name=stoch_signal, i=201, ctr=32
# Error in name=stoch_signal, i=202, ctr=32
# Error in name=stoch_signal, i=203, ctr=32
# Error in name=stoch_signal, i=204, ctr=32
# Error in name=stoch_signal, i=205, ctr=32
# Error in name=stoch_signal, i=206, ctr=32
# Error in name=stoch_signal, i=207, ctr=32
# Error in name=stoch_signal, i=208, ctr=32
# Error in name=stoch_signal, i=209, ctr=32
# Error in name=stoch_signal, i=210, ctr=32
# Error in name=stoch_signal, i=211, ctr=32
# Error in name=stoch_signal, i=212, ctr=32
# Error in name=stoch_signal, i=213, ctr=32
# Error in name=stoch_signal, i=214, ctr=32
# Error in name=stoch_signal, i=215, ctr=32
# Error in name=stoch_signal, i=216, ctr=32
# Error in name=stoch_signal, i=217, ctr=32
# Error in name=stoch_signal, i=218, ctr=32
# Error in name=stoch_signal, i=219, ctr=32
# Error in name=stoch_signal, i=220, ctr=32
# Error in name=stoch_signal, i=221, ctr=32
# Error in name=stoch_signal, i=222, ctr=32
# Error in name=stoch_signal, i=223, ctr=32
# Error in name=stoch_signal, i=224, ctr=32
# Error in name=stoch_signal, i=225, ctr=32
# Error in name=stoch_signal, i=226, ctr=32
# Error in name=stoch_signal, i=227, ctr=32
# Error in name=stoch_signal, i=228, ctr=32
# Error in name=stoch_signal, i=229, ctr=32
# Error in name=stoch_signal, i=230, ctr=32
# Error in name=stoch_signal, i=231, ctr=32
# Error in name=stoch_signal, i=232, ctr=32
# Error in name=stoch_signal, i=233, ctr=32
# Error in name=stoch_signal, i=234, ctr=32
# Error in name=stoch_signal, i=235, ctr=32
# Error in name=stoch_signal, i=236, ctr=32
# Error in name=stoch_signal, i=237, ctr=32
# Error in name=stoch_signal, i=238, ctr=32
# Error in name=stoch_signal, i=239, ctr=32
# Error in name=stoch_signal, i=240, ctr=32
# Error in name=stoch_signal, i=241, ctr=32
# Error in name=stoch_signal, i=242, ctr=32
# Error in name=stoch_signal, i=243, ctr=32
# Error in name=stoch_signal, i=244, ctr=32
# Error in name=stoch_signal, i=245, ctr=32
# Error in name=stoch_signal, i=246, ctr=32
# Error in name=stoch_signal, i=247, ctr=32
# Error in name=stoch_signal, i=248, ctr=32
# Error in name=stoch_signal, i=249, ctr=32
# Error in name=stoch_signal, i=250, ctr=32
# Error in name=stoch_signal, i=251, ctr=32
# Error in name=stoch_signal, i=252, ctr=32
# Error in name=stoch_signal, i=253, ctr=32
# Error in name=stoch_signal, i=254, ctr=32
# Error in name=stoch_signal, i=255, ctr=32
# Error in name=stoch_signal, i=256, ctr=32
# Error in name=stoch_signal, i=257, ctr=32
# Error in name=stoch_signal, i=258, ctr=32
# Error in name=stoch_signal, i=259, ctr=32
# Error in name=stoch_signal, i=260, ctr=32
# Error in name=stoch_signal, i=261, ctr=32
# Error in name=stoch_signal, i=262, ctr=32
# Error in name=stoch_signal, i=263, ctr=32
# Error in name=stoch_signal, i=264, ctr=32
# Error in name=stoch_signal, i=265, ctr=32
# Error in name=stoch_signal, i=266, ctr=32
# Error in name=stoch_signal, i=267, ctr=32
# Error in name=stoch_signal, i=268, ctr=32
# Error in name=stoch_signal, i=269, ctr=32
# Error in name=stoch_signal, i=270, ctr=32
# Error in name=stoch_signal, i=271, ctr=32
# Error in name=stoch_signal, i=272, ctr=32
# Error in name=stoch_signal, i=273, ctr=32
# Error in name=stoch_signal, i=274, ctr=32
# Error in name=stoch_signal, i=275, ctr=32
# Error in name=stoch_signal, i=276, ctr=32
# Error in name=stoch_signal, i=277, ctr=32
# Error in name=stoch_signal, i=278, ctr=32
# Error in name=stoch_signal, i=279, ctr=32
# Error in name=stoch_signal, i=280, ctr=32
# Error in name=stoch_signal, i=281, ctr=32
# Error in name=stoch_signal, i=282, ctr=32
# Error in name=stoch_signal, i=283, ctr=32
# Error in name=stoch_signal, i=284, ctr=32
# Error in name=stoch_signal, i=285, ctr=32
# Error in name=stoch_signal, i=286, ctr=32
# Error in name=stoch_signal, i=287, ctr=32
# Error in name=stoch_signal, i=288, ctr=32
# Error in name=stoch_signal, i=289, ctr=32
# Error in name=stoch_signal, i=290, ctr=32
# Error in name=stoch_signal, i=291, ctr=32
# Error in name=stoch_signal, i=292, ctr=32
# Error in name=stoch_signal, i=293, ctr=32
# Error in name=stoch_signal, i=294, ctr=32
# Error in name=stoch_signal, i=295, ctr=32
# Error in name=stoch_signal, i=296, ctr=32
# Error in name=stoch_signal, i=297, ctr=32
# Error in name=stoch_signal, i=298, ctr=32
# Error in name=stoch_signal, i=299, ctr=32
# Error in name=stoch_signal, i=300, ctr=32
# Error in name=stoch_signal, i=301, ctr=32
# Error in name=stoch_signal, i=302, ctr=32
# Error in name=stoch_signal, i=303, ctr=32
# Error in name=stoch_signal, i=304, ctr=32
# Error in name=stoch_signal, i=305, ctr=32
# Error in name=stoch_signal, i=306, ctr=32
# Error in name=stoch_signal, i=307, ctr=32
# Error in name=stoch_signal, i=308, ctr=32
# Error in name=stoch_signal, i=309, ctr=32
# Error in name=stoch_signal, i=310, ctr=32
# Error in name=stoch_signal, i=311, ctr=32
# Error in name=stoch_signal, i=312, ctr=32
# Error in name=stoch_signal, i=313, ctr=32
# Error in name=stoch_signal, i=314, ctr=32
# Error in name=stoch_signal, i=315, ctr=32
# Error in name=stoch_signal, i=316, ctr=32
# Error in name=stoch_signal, i=317, ctr=32
# Error in name=stoch_signal, i=318, ctr=32
# Error in name=stoch_signal, i=319, ctr=32
# Error in name=stoch_signal, i=320, ctr=32
# Error in name=stoch_signal, i=321, ctr=32
# Error in name=stoch_signal, i=322, ctr=32
# Error in name=stoch_signal, i=323, ctr=32
# Error in name=stoch_signal, i=324, ctr=32
# Error in name=stoch_signal, i=325, ctr=32
# Error in name=stoch_signal, i=326, ctr=32
# Error in name=stoch_signal, i=327, ctr=32
# Error in name=stoch_signal, i=328, ctr=32
# Error in name=stoch_signal, i=329, ctr=32
# Error in name=stoch_signal, i=330, ctr=32
# Error in name=stoch_signal, i=331, ctr=32
# Error in name=stoch_signal, i=332, ctr=32
# Error in name=stoch_signal, i=333, ctr=32
# Error in name=stoch_signal, i=334, ctr=32
# Error in name=stoch_signal, i=335, ctr=32
# Error in name=stoch_signal, i=336, ctr=32
# Error in name=stoch_signal, i=337, ctr=32
# Error in name=stoch_signal, i=338, ctr=32
# Error in name=stoch_signal, i=339, ctr=32
# Error in name=stoch_signal, i=340, ctr=32
# Error in name=stoch_signal, i=341, ctr=32
# Error in name=stoch_signal, i=342, ctr=32
# Error in name=stoch_signal, i=343, ctr=32
# Error in name=stoch_signal, i=344, ctr=32
# Error in name=stoch_signal, i=345, ctr=32
# Error in name=stoch_signal, i=346, ctr=32
# Error in name=stoch_signal, i=347, ctr=32
# Error in name=stoch_signal, i=348, ctr=32
# Error in name=stoch_signal, i=349, ctr=32
# Error in name=stoch_signal, i=350, ctr=32
# Error in name=stoch_signal, i=351, ctr=32
# Error in name=stoch_signal, i=352, ctr=32
# Error in name=stoch_signal, i=353, ctr=32
# Error in name=stoch_signal, i=354, ctr=32
# Error in name=stoch_signal, i=355, ctr=32
# Error in name=stoch_signal, i=356, ctr=32
# Error in name=stoch_signal, i=357, ctr=32
# Error in name=stoch_signal, i=358, ctr=32
# Error in name=stoch_signal, i=359, ctr=32
# Error in name=stoch_signal, i=360, ctr=32
# Error in name=stoch_signal, i=361, ctr=32
# Error in name=stoch_signal, i=362, ctr=32
# Error in name=stoch_signal, i=363, ctr=32
# Error in name=stoch_signal, i=364, ctr=32
# Error in name=stoch_signal, i=365, ctr=32
# Error in name=stoch_signal, i=366, ctr=32
# Error in name=stoch_signal, i=367, ctr=32
# Error in name=stoch_signal, i=368, ctr=32
# Error in name=stoch_signal, i=369, ctr=32
# Error in name=stoch_signal, i=370, ctr=32
# Error in name=stoch_signal, i=371, ctr=32
# Error in name=stoch_signal, i=372, ctr=32
# Error in name=stoch_signal, i=373, ctr=32
# Error in name=stoch_signal, i=374, ctr=32
# Error in name=stoch_signal, i=375, ctr=32
# Error in name=stoch_signal, i=376, ctr=32
# Error in name=stoch_signal, i=377, ctr=32
# Error in name=stoch_signal, i=378, ctr=32
# Error in name=stoch_signal, i=379, ctr=32
# Error in name=stoch_signal, i=380, ctr=32
# Error in name=stoch_signal, i=381, ctr=32
# Error in name=stoch_signal, i=382, ctr=32
# Error in name=stoch_signal, i=383, ctr=32
# Error in name=stoch_signal, i=384, ctr=32
# Error in name=stoch_signal, i=385, ctr=32
# Error in name=stoch_signal, i=386, ctr=32
# Error in name=stoch_signal, i=387, ctr=32
# Error in name=stoch_signal, i=388, ctr=32
# Error in name=stoch_signal, i=389, ctr=32
# Error in name=stoch_signal, i=390, ctr=32
# Error in name=stoch_signal, i=391, ctr=32
# Error in name=stoch_signal, i=392, ctr=32
# Error in name=stoch_signal, i=393, ctr=32
# Error in name=stoch_signal, i=394, ctr=32
# Error in name=stoch_signal, i=395, ctr=32
# Error in name=stoch_signal, i=396, ctr=32
# Error in name=stoch_signal, i=397, ctr=32
# Error in name=stoch_signal, i=398, ctr=32
# Error in name=stoch_signal, i=399, ctr=32
# Error in name=stoch_signal, i=400, ctr=32
# Error in name=stoch_signal, i=401, ctr=32
# Error in name=stoch_signal, i=402, ctr=32
# Error in name=stoch_signal, i=403, ctr=32
# Error in name=stoch_signal, i=404, ctr=32
# Error in name=stoch_signal, i=405, ctr=32
# Error in name=stoch_signal, i=406, ctr=32
# Error in name=stoch_signal, i=407, ctr=32
# Error in name=stoch_signal, i=408, ctr=32
# Error in name=stoch_signal, i=409, ctr=32
# Error in name=stoch_signal, i=410, ctr=32
# Error in name=stoch_signal, i=411, ctr=32
# Error in name=stoch_signal, i=412, ctr=32
# Error in name=stoch_signal, i=413, ctr=32
# Error in name=stoch_signal, i=414, ctr=32
# Error in name=stoch_signal, i=415, ctr=32
# Error in name=stoch_signal, i=416, ctr=32
# Error in name=stoch_signal, i=417, ctr=32
# Error in name=stoch_signal, i=418, ctr=32
# Error in name=stoch_signal, i=419, ctr=32
# Error in name=stoch_signal, i=420, ctr=32
# Error in name=stoch_signal, i=421, ctr=32
# Error in name=stoch_signal, i=422, ctr=32
# Error in name=stoch_signal, i=423, ctr=32
# Error in name=stoch_signal, i=424, ctr=32
# Error in name=stoch_signal, i=425, ctr=32
# Error in name=stoch_signal, i=426, ctr=32
# Error in name=stoch_signal, i=427, ctr=32
# Error in name=stoch_signal, i=428, ctr=32
# Error in name=stoch_signal, i=429, ctr=32
# Error in name=stoch_signal, i=430, ctr=32
# Error in name=stoch_signal, i=431, ctr=32
# Error in name=stoch_signal, i=432, ctr=32
# Error in name=stoch_signal, i=433, ctr=32
# Error in name=stoch_signal, i=434, ctr=32
# Error in name=stoch_signal, i=435, ctr=32
# Error in name=stoch_signal, i=436, ctr=32
# Error in name=stoch_signal, i=437, ctr=32
# Error in name=stoch_signal, i=438, ctr=32
# Error in name=stoch_signal, i=439, ctr=32
# Error in name=stoch_signal, i=440, ctr=32
# Error in name=stoch_signal, i=441, ctr=32
# Error in name=stoch_signal, i=442, ctr=32
# Error in name=stoch_signal, i=443, ctr=32
# Error in name=stoch_signal, i=444, ctr=32
# Error in name=stoch_signal, i=445, ctr=32
# Error in name=stoch_signal, i=446, ctr=32
# Error in name=stoch_signal, i=447, ctr=32
# Error in name=stoch_signal, i=448, ctr=32
# Error in name=stoch_signal, i=449, ctr=32
# Error in name=stoch_signal, i=450, ctr=32
# Error in name=stoch_signal, i=451, ctr=32
# Error in name=stoch_signal, i=452, ctr=32
# Error in name=stoch_signal, i=453, ctr=32
# Error in name=stoch_signal, i=454, ctr=32
# Error in name=stoch_signal, i=455, ctr=32
# Error in name=stoch_signal, i=456, ctr=32
# Error in name=stoch_signal, i=457, ctr=32
# Error in name=stoch_signal, i=458, ctr=32
# Error in name=stoch_signal, i=459, ctr=32
# Error in name=stoch_signal, i=460, ctr=32
# Error in name=stoch_signal, i=461, ctr=32
# Error in name=stoch_signal, i=462, ctr=32
# Error in name=stoch_signal, i=463, ctr=32
# Error in name=stoch_signal, i=464, ctr=32
# Error in name=stoch_signal, i=465, ctr=32
# Error in name=stoch_signal, i=466, ctr=32
# Error in name=stoch_signal, i=467, ctr=32
# Error in name=stoch_signal, i=468, ctr=32
# Error in name=stoch_signal, i=469, ctr=32
# Error in name=stoch_signal, i=470, ctr=32
# Error in name=stoch_signal, i=471, ctr=32
# Error in name=stoch_signal, i=472, ctr=32
# Error in name=stoch_signal, i=473, ctr=32
# Error in name=stoch_signal, i=474, ctr=32
# Error in name=stoch_signal, i=475, ctr=32
# Error in name=stoch_signal, i=476, ctr=32
# Error in name=stoch_signal, i=477, ctr=32
# Error in name=stoch_signal, i=478, ctr=32
# Error in name=stoch_signal, i=479, ctr=32
# Error in name=stoch_signal, i=480, ctr=32
# Error in name=stoch_signal, i=481, ctr=32
# Error in name=stoch_signal, i=482, ctr=32
# Error in name=stoch_signal, i=483, ctr=32
# Error in name=stoch_signal, i=484, ctr=32
# Error in name=stoch_signal, i=485, ctr=32
# Error in name=stoch_signal, i=486, ctr=32
# Error in name=stoch_signal, i=487, ctr=32
# Error in name=stoch_signal, i=488, ctr=32
# Error in name=stoch_signal, i=489, ctr=32
# Error in name=stoch_signal, i=490, ctr=32
# Error in name=stoch_signal, i=491, ctr=32
# Error in name=stoch_signal, i=492, ctr=32
# Error in name=stoch_signal, i=493, ctr=32
# Error in name=stoch_signal, i=494, ctr=32
# Error in name=stoch_signal, i=495, ctr=32
# Error in name=stoch_signal, i=496, ctr=32
# Error in name=stoch_signal, i=497, ctr=32
# Error in name=stoch_signal, i=498, ctr=32
# Error in name=stoch_signal, i=499, ctr=32
# Error in name=stoch_signal, i=500, ctr=32
# Error in name=stoch_signal, i=501, ctr=32
# Error in name=stoch_signal, i=502, ctr=32
# Error in name=stoch_signal, i=503, ctr=32
# Error in name=stoch_signal, i=504, ctr=32
# Error in name=stoch_signal, i=505, ctr=32
# Error in name=stoch_signal, i=506, ctr=32
# Error in name=stoch_signal, i=507, ctr=32
# Error in name=stoch_signal, i=508, ctr=32
# Error in name=stoch_signal, i=509, ctr=32
# Error in name=stoch_signal, i=510, ctr=32
# Error in name=stoch_signal, i=511, ctr=32
# Error in name=stoch_signal, i=512, ctr=32
# Error in name=stoch_signal, i=513, ctr=32
# Error in name=stoch_signal, i=514, ctr=32
# Error in name=stoch_signal, i=515, ctr=32
# Error in name=stoch_signal, i=516, ctr=32
# Error in name=stoch_signal, i=517, ctr=32
# Error in name=stoch_signal, i=518, ctr=32
# Error in name=stoch_signal, i=519, ctr=32
# Error in name=stoch_signal, i=520, ctr=32
# Error in name=stoch_signal, i=521, ctr=32
# Error in name=stoch_signal, i=522, ctr=32
# Error in name=stoch_signal, i=523, ctr=32
# Error in name=stoch_signal, i=524, ctr=32
# Error in name=stoch_signal, i=525, ctr=32
# Error in name=stoch_signal, i=526, ctr=32
# Error in name=stoch_signal, i=527, ctr=32
# Error in name=stoch_signal, i=528, ctr=32
# Error in name=stoch_signal, i=529, ctr=32
# Error in name=stoch_signal, i=530, ctr=32
# Error in name=stoch_signal, i=531, ctr=32
# Error in name=stoch_signal, i=532, ctr=32
# Error in name=stoch_signal, i=533, ctr=32
# Error in name=stoch_signal, i=534, ctr=32
# Error in name=stoch_signal, i=535, ctr=32
# Error in name=stoch_signal, i=536, ctr=32
# Error in name=stoch_signal, i=537, ctr=32
# Error in name=stoch_signal, i=538, ctr=32
# Error in name=stoch_signal, i=539, ctr=32
# Error in name=stoch_signal, i=540, ctr=32
# Error in name=stoch_signal, i=541, ctr=32
# Error in name=stoch_signal, i=542, ctr=32
# Error in name=stoch_signal, i=543, ctr=32
# Error in name=stoch_signal, i=544, ctr=32
# Error in name=stoch_signal, i=545, ctr=32
# Error in name=stoch_signal, i=546, ctr=32
# Error in name=stoch_signal, i=547, ctr=32
# Error in name=stoch_signal, i=548, ctr=32
# Error in name=stoch_signal, i=549, ctr=32
# Error in name=stoch_signal, i=550, ctr=32
# Error in name=stoch_signal, i=551, ctr=32
# Error in name=stoch_signal, i=552, ctr=32
# Error in name=stoch_signal, i=553, ctr=32
# Error in name=stoch_signal, i=554, ctr=32
# Error in name=stoch_signal, i=555, ctr=32
# Error in name=stoch_signal, i=556, ctr=32
# Error in name=stoch_signal, i=557, ctr=32
# Error in name=stoch_signal, i=558, ctr=32
# Error in name=stoch_signal, i=559, ctr=32
# Error in name=stoch_signal, i=560, ctr=32
# Error in name=stoch_signal, i=561, ctr=32
# Error in name=stoch_signal, i=562, ctr=32
# Error in name=stoch_signal, i=563, ctr=32
# Error in name=stoch_signal, i=564, ctr=32
# Error in name=stoch_signal, i=565, ctr=32
# Error in name=stoch_signal, i=566, ctr=32
# Error in name=stoch_signal, i=567, ctr=32
# Error in name=stoch_signal, i=568, ctr=32
# Error in name=stoch_signal, i=569, ctr=32
# Error in name=stoch_signal, i=570, ctr=32
# Error in name=stoch_signal, i=571, ctr=32
# Error in name=stoch_signal, i=572, ctr=32
# Error in name=stoch_signal, i=573, ctr=32
# Error in name=stoch_signal, i=574, ctr=32
# Error in name=stoch_signal, i=575, ctr=32
# Error in name=stoch_signal, i=576, ctr=32
# Error in name=stoch_signal, i=577, ctr=32
# Error in name=stoch_signal, i=578, ctr=32
# Error in name=stoch_signal, i=579, ctr=32
# Error in name=stoch_signal, i=580, ctr=32
# Error in name=stoch_signal, i=581, ctr=32
# Error in name=stoch_signal, i=582, ctr=32
# Error in name=stoch_signal, i=583, ctr=32
# Error in name=stoch_signal, i=584, ctr=32
# Error in name=stoch_signal, i=585, ctr=32
# Error in name=stoch_signal, i=586, ctr=32
# Error in name=stoch_signal, i=587, ctr=32
# Error in name=stoch_signal, i=588, ctr=32
# Error in name=stoch_signal, i=589, ctr=32
# Error in name=stoch_signal, i=590, ctr=32
# Error in name=stoch_signal, i=591, ctr=32
# Error in name=stoch_signal, i=592, ctr=32
# Error in name=stoch_signal, i=593, ctr=32
# Error in name=stoch_signal, i=594, ctr=32
# Error in name=stoch_signal, i=595, ctr=32
# Error in name=stoch_signal, i=596, ctr=32
# Error in name=stoch_signal, i=597, ctr=32
# Error in name=stoch_signal, i=598, ctr=32
# Error in name=stoch_signal, i=599, ctr=32
# Error in name=stoch_signal, i=600, ctr=32
# Error in name=stoch_signal, i=601, ctr=32
# Error in name=stoch_signal, i=602, ctr=32
# Error in name=stoch_signal, i=603, ctr=32
# Error in name=stoch_signal, i=604, ctr=32
# Error in name=stoch_signal, i=605, ctr=32
# Error in name=stoch_signal, i=606, ctr=32
# Error in name=stoch_signal, i=607, ctr=32
# Error in name=stoch_signal, i=608, ctr=32
# Error in name=stoch_signal, i=609, ctr=32
# Error in name=stoch_signal, i=610, ctr=32
# Error in name=stoch_signal, i=611, ctr=32
# Error in name=stoch_signal, i=612, ctr=32
# Error in name=stoch_signal, i=613, ctr=32
# Error in name=stoch_signal, i=614, ctr=32
# Error in name=stoch_signal, i=615, ctr=32
# Error in name=stoch_signal, i=616, ctr=32
# Error in name=stoch_signal, i=617, ctr=32
# Error in name=stoch_signal, i=618, ctr=32
# Error in name=stoch_signal, i=619, ctr=32
# Error in name=stoch_signal, i=620, ctr=32
# Error in name=stoch_signal, i=621, ctr=32
# Error in name=stoch_signal, i=622, ctr=32
# Error in name=stoch_signal, i=623, ctr=32
# Error in name=stoch_signal, i=624, ctr=32
# Error in name=stoch_signal, i=625, ctr=32
# Error in name=stoch_signal, i=626, ctr=32
# Error in name=stoch_signal, i=627, ctr=32
# Error in name=stoch_signal, i=628, ctr=32
# Error in name=stoch_signal, i=629, ctr=32
# Error in name=stoch_signal, i=630, ctr=32
# Error in name=stoch_signal, i=631, ctr=32
# Error in name=stoch_signal, i=632, ctr=32
# Error in name=stoch_signal, i=633, ctr=32
# Error in name=stoch_signal, i=634, ctr=32
# Error in name=stoch_signal, i=635, ctr=32
# Error in name=stoch_signal, i=636, ctr=32
# Error in name=stoch_signal, i=637, ctr=32
# Error in name=stoch_signal, i=638, ctr=32
# Error in name=stoch_signal, i=639, ctr=32
# Error in name=stoch_signal, i=640, ctr=32
# Error in name=stoch_signal, i=641, ctr=32
# Error in name=stoch_signal, i=642, ctr=32
# Error in name=stoch_signal, i=643, ctr=32
# Error in name=stoch_signal, i=644, ctr=32
# Error in name=stoch_signal, i=645, ctr=32
# Error in name=stoch_signal, i=646, ctr=32
# Error in name=stoch_signal, i=647, ctr=32
# Error in name=stoch_signal, i=648, ctr=32
# Error in name=stoch_signal, i=649, ctr=32
# Error in name=stoch_signal, i=650, ctr=32
# Error in name=stoch_signal, i=651, ctr=32
# Error in name=stoch_signal, i=652, ctr=32
# Error in name=stoch_signal, i=653, ctr=32
# Error in name=stoch_signal, i=654, ctr=32
# Error in name=stoch_signal, i=655, ctr=32
# Error in name=stoch_signal, i=656, ctr=32
# Error in name=stoch_signal, i=657, ctr=32
# Error in name=stoch_signal, i=658, ctr=32
# Error in name=stoch_signal, i=659, ctr=32
# Error in name=stoch_signal, i=660, ctr=32
# Error in name=stoch_signal, i=661, ctr=32
# Error in name=stoch_signal, i=662, ctr=32
# Error in name=stoch_signal, i=663, ctr=32
# Error in name=stoch_signal, i=664, ctr=32
# Error in name=stoch_signal, i=665, ctr=32
# Error in name=stoch_signal, i=666, ctr=32
# Error in name=stoch_signal, i=667, ctr=32
# Error in name=stoch_signal, i=668, ctr=32
# Error in name=stoch_signal, i=669, ctr=32
# Error in name=stoch_signal, i=670, ctr=32
# Error in name=stoch_signal, i=671, ctr=32
# Error in name=stoch_signal, i=672, ctr=32
# Error in name=stoch_signal, i=673, ctr=32
# Error in name=stoch_signal, i=674, ctr=32
# Error in name=stoch_signal, i=675, ctr=32
# Error in name=stoch_signal, i=676, ctr=32
# Error in name=stoch_signal, i=677, ctr=32
# Error in name=stoch_signal, i=678, ctr=32
# Error in name=stoch_signal, i=679, ctr=32
# Error in name=stoch_signal, i=680, ctr=32
# Error in name=stoch_signal, i=681, ctr=32
# Error in name=stoch_signal, i=682, ctr=32
# Error in name=stoch_signal, i=683, ctr=32
# Error in name=stoch_signal, i=684, ctr=32
# Error in name=stoch_signal, i=685, ctr=32
# Error in name=stoch_signal, i=686, ctr=32
# Error in name=stoch_signal, i=687, ctr=32
# Error in name=stoch_signal, i=688, ctr=32
# Error in name=stoch_signal, i=689, ctr=32
# Error in name=stoch_signal, i=690, ctr=32
# Error in name=stoch_signal, i=691, ctr=32
# Error in name=stoch_signal, i=692, ctr=32
# Error in name=stoch_signal, i=693, ctr=32
# Error in name=stoch_signal, i=694, ctr=32
# Error in name=stoch_signal, i=695, ctr=32
# Error in name=stoch_signal, i=696, ctr=32
# Error in name=stoch_signal, i=697, ctr=32
# Error in name=stoch_signal, i=698, ctr=32
# Error in name=stoch_signal, i=699, ctr=32
# Error in name=stoch_signal, i=700, ctr=32
# Error in name=stoch_signal, i=701, ctr=32
# Error in name=stoch_signal, i=702, ctr=32
# Error in name=stoch_signal, i=703, ctr=32
# Error in name=stoch_signal, i=704, ctr=32
# Error in name=stoch_signal, i=705, ctr=32
# Error in name=stoch_signal, i=706, ctr=32
# Error in name=stoch_signal, i=707, ctr=32
# Error in name=stoch_signal, i=708, ctr=32
# Error in name=stoch_signal, i=709, ctr=32
# Error in name=stoch_signal, i=710, ctr=32
# Error in name=stoch_signal, i=711, ctr=32
# Error in name=stoch_signal, i=712, ctr=32
# Error in name=stoch_signal, i=713, ctr=32
# Error in name=stoch_signal, i=714, ctr=32
# Error in name=stoch_signal, i=715, ctr=32
# Error in name=stoch_signal, i=716, ctr=32
# Error in name=stoch_signal, i=717, ctr=32
# Error in name=stoch_signal, i=718, ctr=32
# Error in name=stoch_signal, i=719, ctr=32
# Error in name=stoch_signal, i=720, ctr=32
# Error in name=stoch_signal, i=721, ctr=32
# Error in name=stoch_signal, i=722, ctr=32
# Error in name=stoch_signal, i=723, ctr=32
# Error in name=stoch_signal, i=724, ctr=32
# Error in name=stoch_signal, i=725, ctr=32
# Error in name=stoch_signal, i=726, ctr=32
# Error in name=stoch_signal, i=727, ctr=32
# Error in name=stoch_signal, i=728, ctr=32
# Error in name=stoch_signal, i=729, ctr=32
# Error in name=stoch_signal, i=730, ctr=32
# Error in name=stoch_signal, i=731, ctr=32
# Error in name=stoch_signal, i=732, ctr=32
# Error in name=stoch_signal, i=733, ctr=32
# Error in name=stoch_signal, i=734, ctr=32
# Error in name=stoch_signal, i=735, ctr=32
# Error in name=stoch_signal, i=736, ctr=32
# Error in name=stoch_signal, i=737, ctr=32
# Error in name=stoch_signal, i=738, ctr=32
# Error in name=stoch_signal, i=739, ctr=32
# Error in name=stoch_signal, i=740, ctr=32
# Error in name=stoch_signal, i=741, ctr=32
# Error in name=stoch_signal, i=742, ctr=32
# Error in name=stoch_signal, i=743, ctr=32
# Error in name=stoch_signal, i=744, ctr=32
# Error in name=stoch_signal, i=745, ctr=32
# Error in name=stoch_signal, i=746, ctr=32
# Error in name=stoch_signal, i=747, ctr=32
# Error in name=stoch_signal, i=748, ctr=32
# Error in name=stoch_signal, i=749, ctr=32
# Error in name=stoch_signal, i=750, ctr=32
# Error in name=stoch_signal, i=751, ctr=32
# Error in name=stoch_signal, i=752, ctr=32
# Error in name=stoch_signal, i=753, ctr=32
# Error in name=stoch_signal, i=754, ctr=32
# Error in name=stoch_signal, i=755, ctr=32
# Error in name=stoch_signal, i=756, ctr=32
# Error in name=stoch_signal, i=757, ctr=32
# Error in name=stoch_signal, i=758, ctr=32
# Processing = wr
# Processing = ao
# Processing = daily_return

# %%
Xr.to_clipboard(excel=True, sep=None)

# %%
tmp = [0]
Xr.iloc[i,ctr] = tmp[-1]

# %%
#Check the same model with 2 day lag to check how it performs
